# %%
theta1 <- c(5.3, 10.2, 1.2, 15.2)
mean1 <- sum(theta1) / length(theta1)
sd1 <- 6.5^2 / 4

# %%
samples <- rnorm(1000, mean1, sd1)

# %%
plot(density(samples))
# Out:
# Plot with title "density.default(x = samples)"

# %%
theta2 <- c(5.3, 10.2, 1.2, 15.2)
mean2 <- sum(theta2) / length(theta2)
sd2 <- 6.5^2 / length(theta2)
samples2 <- rnorm(1000, mean2, sd2)
plot(density(samples2))
# Out:
# Plot with title "density.default(x = samples2)"

# %%
theta1 <- c(5.3, 10.2, 1.2, 15.2)
mean1 <- sum(theta1) / length(theta1)
sd1 <- sqrt(6.5^2 / 4)
samples_theta1 <- rnorm(1000, mean1, sd1)

theta2 <- c(2.3, -5.5, 2.2, 10.1)
mean2 <- sum(theta2) / length(theta2)
sd2 <- sqrt(6.5^2 / 4)
samples_theta2 <- rnorm(1000, mean2, sd2)

delta_samples <- samples_theta1 - samples_theta2
t(delta_samples)
# Out:
#      [,1]     [,2]     [,3]     [,4]     [,5]     [,6]    [,7]     [,8]
# [1,] 5.024343 11.79759 5.448785 5.391696 2.543768 8.24295 3.956801 10.24232
#      [,9]      [,10]    [,11] [,12]    [,13]    [,14]    [,15]    [,16]
# [1,] 0.7536903 -1.62816 ...   9.822129 2.347279 7.532474 2.477333 7.351743
#      [,17]    [,18]    [,19]   [,20]    [,21]
# [1,] 4.352392 5.858651 7.67338 2.910943 15.88578

# %%
plot(density(delta_samples))
# Out:
# Plot with title "density.default(x = delta_samples)"

# %%
posterior.mean <- mean(delta_samples)
posterior.mean
posterior.sd <- sd(delta_samples)
posterior.sd
posterior.credibility <- quantile(delta_samples, c(0.025,0.975))
posterior.credibility
# Out:
# [1] 5.756244
# [1] 4.496774
#      2.5%     97.5%
# -2.877138 14.126118

# %%
hist(delta_samples)
# Out:
# Plot with title "Histogram of delta_samples"
